# %%
import warnings
warnings.simplefilter("ignore")

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import preprocessing
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  

# %matplotlib inline
np.random.seed(42)

# %% [markdown]
# __<font size="6">Table of Contents</font>__
#
#
# * [Introduction](#Introduction)
# * [Data description](#Description)
# * [Data Preparation](#Description)
#     * [Data Transformation](#Transformation)
#     * [Descretization](#descretization)
#     * [Feature Engineerin](#feature)
#     * [Missing values](#Missing)
#     * [Outliers](#Outliers)
#     * [Duplicates](#Duplicates)
#
# * [Exploratory Data Analysis](#EDA)
#     * [Univariate Analysis](#Univar)
#     * [Bivariate analysis](#Bivar)
#     * [Other sections EDA](#OtherEDA)
# * [Modelling](#Modelling)
#     * [Using DecisionTree Classifier](#Model1)
#     * [Using Random Forest Classifier](#Model2)
#     * [Using Gradient Boosting Clissifier](#Model3)
#     * [Performance evaluation](#Performance)
#     * [Testing the best Model](#Test)
#     * [Conclusions](#Conclusions)

# %%
df = pd.read_csv("data/postpartum-depression.csv")

# %%
df.head()
# Out:
#     Age  Gestational Age  Number of sons   Number of daughters  \
# 0  25.0               26                0                    0
# 1  28.0               35                0                    1
# 2  26.0               28                0                    0
# 3  25.0               28                0                    1
# 4  24.0               39                0                    0
#
#    Total Number of Children       Gravida Female Education Husband Education  \
# 0                         0  Primigravida       Graduation        Graduation
# 1                         1  Multigravida     Intermediate            Matric
# 2                         0  Primigravida       Graduation        Graduation
# 3                         1  Multigravida       Graduation        Graduation
# 4                         0  Primigravida       Graduation        Graduation
#
#   Working Status Physical Health   ... Feeling down, depressed, or hopeless  \
# 0      Housewife          Healthy  ...                                    3
# 1  Working Lady           Healthy  ...                                    2
# 2      Housewife          Healthy  ...                                    1
# 3      Housewife          Healthy  ...                                    0
# 4      Housewife          Healthy  ...                                    1
#
#   Trouble falling or staying sleep or sleeping too much  \
# 0                                                  1
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  0
#
#   Feeling tired or having little energy Poor appetite or overeating  \
# 0                                     1                           2
# 1                                     0                           3
# 2                                     2                           0
# 3                                     3                           3
# 4                                     1                           1
#
#   Feeling badabout yourself that you are failure or have let yourself or your family down  \
# 0                                                  2
# 1                                                  1
# 2                                                  3
# 3                                                  1
# 4                                                  0
#
#   Trouble concentrating on things, such as reading the newspaper or watching television   \
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  0
#
#    Moving or speaking so slowly that other people could have Noticed.   \
# 0                                                2.0
# 1                                                0.0
# 2                                                0.0
# 3                                                3.0
# 4                                                0.0
#
#    Thoughts that you would be better off dead, or of hurting yourself  \
# 0                                                1.0
# 1                                                1.0
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
#    Scalling  Labelling
# 0        16  Depressed
# 1        13  Depressed
# 2        13  Depressed
# 3        17  Depressed
# 4         5       Not
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14008 entries, 0 to 14007
# Data columns (total 27 columns):
#  #   Column                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                   --------------  -----
#  0   Age                                                                                      14006 non-null  float64
#  1   Gestational Age                                                                          14008 non-null  int64
#  2   Number of sons                                                                           14008 non-null  int64
#  3   Number of daughters                                                                      14008 non-null  int64
#  4   Total Number of Children                                                                 14008 non-null  int64
#  5   Gravida                                                                                  14008 non-null  object
#  6   Female Education                                                                         14008 non-null  object
#  7   Husband Education                                                                        14008 non-null  object
#  8   Working Status                                                                           14008 non-null  object
#  9   Physical Health                                                                          14008 non-null  object
#  10  Previous Miscarriage                                                                     14008 non-null  object
#  11  Sufficient Money for Basic Needs                                                         14004 non-null  object
#  12  Current Appereance Acceptance                                                            14008 non-null  object
#  13  Family System                                                                            14008 non-null  object
#  14  Male Gender Preference                                                                   14006 non-null  object
#  15  Relationship with Mother in-law                                                          14008 non-null  object
#  16  Little interest or pleasure in doing things                                              14008 non-null  int64
#  17  Feeling down, depressed, or hopeless                                                     14008 non-null  int64
#  18  Trouble falling or staying sleep or sleeping too much                                    14008 non-null  int64
#  19  Feeling tired or having little energy                                                    14008 non-null  int64
#  20  Poor appetite or overeating                                                              14008 non-null  int64
#  21  Feeling badabout yourself that you are failure or have let yourself or your family down  14008 non-null  int64
#  22  Trouble concentrating on things, such as reading the newspaper or watching television    14008 non-null  int64
#  23  Moving or speaking so slowly that other people could have Noticed.                       14002 non-null  float64
#  24  Thoughts that you would be better off dead, or of hurting yourself                       14004 non-null  float64
#  25  Scalling                                                                                 14008 non-null  int64
#  26  Labelling                                                                                14008 non-null  object
# dtypes: float64(3), int64(12), object(12)
# memory usage: 2.9+ MB
